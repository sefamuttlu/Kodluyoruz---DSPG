# %%
import pandas as pd
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df=pd.read_csv("Desktop/test/archive/aa.csv",encoding='latin-1', index_col="Unnamed: 0")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1000 non-null   object
#  1   artist     1000 non-null   object
#  2   top genre  985 non-null    object
#  3   year       1000 non-null   int64
#  4   added      1000 non-null   object
#  5   bpm        999 non-null    float64
#  6   nrgy       999 non-null    float64
#  7   dnce       999 non-null    float64
#  8   dB         999 non-null    float64
#  9   live       999 non-null    float64
#  10  val        999 non-null    float64
#  11  dur        1000 non-null   int64
#  12  acous      999 non-null    float64
#  13  spch       999 non-null    float64
#  14  pop        1000 non-null   int64
#  15  country    1000 non-null   object
# dtypes: float64(8), int64(3), object(5)
# memory usage: 132.8+ KB

# %%
df
# Out:
#                                 title          artist          top genre  \
# 1                        Dance Monkey     Tones and I     australian pop
# 2                             ROXANNE  Arizona Zervas            pop rap
# 3                            Memories        Maroon 5                pop
# 4                             Circles     Post Malone            dfw rap
# 5     All I Want for Christmas Is You    Mariah Carey          dance pop
# ...                               ...             ...                ...
# 996                          Feelings            Lauv                pop
# 997                Mimpi (feat. Alif)        K-Clique    malaysian indie
# 998                  Cinta Luar Biasa         Andmesh     indonesian pop
# 999                         Haa Tepok         MeerFly  malaysian hip hop
# 1000                      Hanya Rindu         Andmesh     indonesian pop
#
#       year       added    bpm  nrgy  dnce    dB  live   val  dur  acous  spch  \
# ...

# %%
df["added"].unique()
# Out:
# array(['1969-12-31'], dtype=object)

# %%
df.drop(columns=["added"], inplace=True)

# %%
df.sample(5)
# Out:
#                                                  title         artist  \
# 16            It's the Most Wonderful Time of the Year  Andy Williams
# 165  Let It Snow! Let It Snow! Let It Snow! (with T...  Frank Sinatra
# 450                                          Skifahren     The Cratez
# 852                                           Memories       Maroon 5
# 565                                   Yo x Ti, Tu x Mi        ROSALÍA
#
#            top genre  year    bpm  nrgy  dnce    dB  live   val  dur  acous  \
# 16   adult standards  1963  202.0  60.0  24.0  -8.0  12.0  78.0  152   77.0
# 165  adult standards  1994  142.0  26.0  65.0 -13.0  36.0  84.0  155   90.0
# 450   german hip hop  2019  134.0  71.0  72.0  -7.0  15.0  44.0  163   22.0
# 852              pop  2019   91.0  32.0  76.0  -7.0   8.0  57.0  189   84.0
# 565   r&b en espanol  2019   92.0  76.0  78.0  -3.0  14.0  58.0  201   46.0
#
#      spch  pop    country
# 16    4.0   92      world
# 165   6.0   91  australia
# ...

# %%
df.sort_values(by="pop", ascending=False)
# Out:
#                                                  title           artist  \
# 1                                         Dance Monkey      Tones and I
# 51                                        Dance Monkey      Tones and I
# 951                                       Dance Monkey      Tones and I
# 851                                       Dance Monkey      Tones and I
# 801                                       Dance Monkey      Tones and I
# ..                                                 ...              ...
# 98                                           Akulaleki  Samthing Soweto
# 850   Ve'Eem Tavo'ee Elay (And If You Will Come To Me)     Idan Raichel
# 949                                   Teenager Forever         King Gnu
# 100  Love You Tonight (feat. DJ Maphorisa, Sha Sha ...        Mfr Souls
# 950  <U+5C0F><U+3055><U+306A><U+604B><U+306E><U+304...        MONGOL800
#
#                top genre  year    bpm  nrgy  dnce   dB  live   val  dur  \
# ...

# %%
df["title"].value_counts()
# Out:
# Dance Monkey                                                17
# ROXANNE                                                     14
# All I Want for Christmas Is You                             14
# Last Christmas                                              13
# Señorita                                                    11
#                                                             ..
# <U+30DE><U+30EA><U+30FC><U+30B4><U+30FC><U+30EB><U+30C9>     1
# Chama Ela (feat. Pedro Sampaio)                              1
# Petit Papa Noël                                              1
# Reste                                                        1
# In der Weihnachtsbäckerei                                    1
# Name: title, Length: 527, dtype: int64

# %%
d = dict(df["title"].value_counts().head())

# %%
plt.barh(list(d.keys()), list(d.values()))

plt.title("Top 5 Songs")

plt.tight_layout()
plt.show()

# %%
df["top genre"].unique()
# Out:
# array(['australian pop', 'pop rap', 'pop', 'dfw rap', 'dance pop',
#        'electropop', 'alternative r&b', 'latin',
#        'canadian contemporary r&b', 'adult standards', 'album rock',
#        'canadian pop', nan, 'blues rock', 'glam rock', 'permanent wave',
#        'celtic punk', 'heartland rock', 'new wave pop', 'latin pop',
#        'afro house', 'amapiano', 'kwaito', 'kwaito house',
#        'pop reggaeton', 'colombian pop', 'reggaeton', 'panamanian pop',
#        'r&b en espanol', 'argentine hip hop', 'argentine indie',
#        'cumbia pop', 'cumbia villera', 'argentine rock', 'trap argentino',
#        'cumbia chilena', 'pop edm', 'baroque pop', 'hollywood', 'disco',
#        'australian alternative rock', 'french hip hop', 'dutch cabaret',
#        'chicago soul', 'grupera', 'baile pop', 'brega funk', 'sertanejo',
#        'sertanejo universitario', 'funk carioca', 'sertanejo pop',
#        'pop nacional', 'axe', 'brazilian edm', 'forro', 'melodic rap',
# ...

# %%
filter_genre = ["pop", "rock", "hip hop", "rap"]

# %%
a = df["top genre"].isin(filter_genre)

# %%
newdf = df.loc[a]

# %%
newdf
# Out:
#                                       title         artist top genre  year  \
# 3                                  Memories       Maroon 5       pop  2019
# 12                        Someone You Loved  Lewis Capaldi       pop  2019
# 24   Have Yourself A Merry Little Christmas      Sam Smith       pop  2014
# 53                                 Memories       Maroon 5       pop  2019
# 67   Have Yourself A Merry Little Christmas      Sam Smith       pop  2014
# 77          Beautiful People (feat. Khalid)     Ed Sheeran       pop  2019
# 154                                Memories       Maroon 5       pop  2019
# 168  Have Yourself A Merry Little Christmas      Sam Smith       pop  2014
# 203                                Memories       Maroon 5       pop  2019
# 209                       Someone You Loved  Lewis Capaldi       pop  2019
# 223  Have Yourself A Merry Little Christmas      Sam Smith       pop  2014
# ...

# %% [markdown]
# #####3 regex ??

# %%
filtrock=df["top genre"].str.contains("rock", na=False)

# %%
filtrap=df["top genre"].str.contains("rap", na=False)

# %%
filthiphop=df["top genre"].str.contains("hip hop", na=False)

# %%
filtpop=df["top genre"].str.contains("pop", na=False)

# %%
df.loc[filtpop, "top genre"] = "pop"

# %%
df.loc[filtrock, "top genre"] = "rock"

# %%
df.loc[filthiphop, "top genre"] = "hip hop"

# %%
df.loc[filtrap, "top genre"] = "rap"

# %%
df
# Out:
#                                 title          artist        top genre  year  \
# 1                        Dance Monkey     Tones and I              pop  2019
# 2                             ROXANNE  Arizona Zervas              rap  2019
# 3                            Memories        Maroon 5              pop  2019
# 4                             Circles     Post Malone              rap  2019
# 5     All I Want for Christmas Is You    Mariah Carey              pop  1994
# ...                               ...             ...              ...   ...
# 996                          Feelings            Lauv              pop  2019
# 997                Mimpi (feat. Alif)        K-Clique  malaysian indie  2019
# 998                  Cinta Luar Biasa         Andmesh              pop  2019
# 999                         Haa Tepok         MeerFly          hip hop  2019
# 1000                      Hanya Rindu         Andmesh              pop  2019
#
# ...

# %%
df["top genre"].value_counts()
# Out:
# pop                          365
# adult standards              145
# latin                        113
# hip hop                       66
# rock                          66
# rap                           55
# israeli mediterranean         13
# cumbia                        11
# sertanejo                     11
# funk carioca                  10
# alternative r&b                9
# indonesian indie               9
# canadian contemporary r&b      8
# afro house                     8
# reggaeton                      8
# r&b en espanol                 8
# j-acoustic                     7
# sertanejo universitario        7
# francoton                      6
# permanent wave                 5
# celtic punk                    4
# contemporary country           3
# hollywood                      3
# dembow                         3
# brega funk                     3
# bolero                         3
# electro house                  2
# grupera                        2
# ...

# %%
genre = df["top genre"].value_counts().head(6)

# %%
genre
# Out:
# pop                365
# adult standards    145
# latin              113
# hip hop             66
# rock                66
# rap                 55
# Name: top genre, dtype: int64

# %%
labels=["pop", "adult standards", "latin ", "hip hop", "rock", "rap"]
plt.pie(genre, labels=labels)

plt.title("most listened genres")

plt.tight_layout()
plt.show()

# %%
df["country"].unique()
# Out:
# array(['world', 'africa', 'argentina', 'australia', 'belgium', 'bolivia',
#        'brazil', 'canada', 'germany', 'colombia', 'chile', 'spain', 'usa',
#        'france', 'india', 'indonesia', 'israel', 'italy', 'japan',
#        'malasya'], dtype=object)

# %%
country_group = df.groupby("country")

# %%
country_group["top genre"].value_counts()
# Out:
# country  top genre
# africa   adult standards              17
#          pop                          14
#          afro house                    8
#          rock                          4
#          rap                           2
#                                       ..
# world    alternative r&b               1
#          canadian contemporary r&b     1
#          celtic punk                   1
#          latin                         1
#          permanent wave                1
# Name: top genre, Length: 165, dtype: int64

# %%
italy = country_group["top genre"].value_counts()["italy"].head()

# %%
italy
# Out:
# top genre
# pop                16
# hip hop            12
# rap                 9
# adult standards     8
# rock                3
# Name: top genre, dtype: int64

# %%
argentina = country_group["top genre"].value_counts()["argentina"].head()

# %%
argentina
# Out:
# top genre
# latin             21
# pop               11
# rock               5
# hip hop            3
# cumbia villera     2
# Name: top genre, dtype: int64

# %%
a = dict(country_group["top genre"].value_counts()["argentina"].head())

# %%
i = dict(country_group["top genre"].value_counts()["italy"].head())

# %%
fig = plt.figure(figsize=(15,5))
plt.subplots_adjust(wspace=0.7)

ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.pie(italy, labels=i.keys())
ax2.pie(argentina, labels=a.keys())

ax1.set_title("italy")
ax2.set_title("argentina")

plt.tight_layout()

plt.show()

# %%
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

ax1.pie(germany)
ax2.pie(canada)

plt.tight_layout()

plt.show()

# %%
genre_group = df.groupby("top genre")

# %%
genre_group["dur"].mean().nlargest()
# Out:
# top genre
# perreo          464.00
# afro house      399.25
# amapiano        384.00
# kwaito house    343.00
# chicha          287.00
# Name: dur, dtype: float64

# %%
df.loc[df["pop"]>95]
# Out:
#                                title          artist  \
# 1                       Dance Monkey     Tones and I
# 2                            ROXANNE  Arizona Zervas
# 3                           Memories        Maroon 5
# 4                            Circles     Post Malone
# 5    All I Want for Christmas Is You    Mariah Carey
# ..                               ...             ...
# 959              Lose You To Love Me    Selena Gomez
# 960                Someone You Loved   Lewis Capaldi
# 961                  hot girl bummer       blackbear
# 962                  Blinding Lights      The Weeknd
# 963                          bad guy   Billie Eilish
#
#                      top genre  year    bpm  nrgy  dnce    dB  live   val  \
# 1                          pop  2019   98.0  59.0  82.0  -6.0  15.0  51.0
# 2                          rap  2019  117.0  60.0  62.0  -6.0  46.0  46.0
# 3                          pop  2019   91.0  32.0  76.0  -7.0   8.0  57.0
# ...
